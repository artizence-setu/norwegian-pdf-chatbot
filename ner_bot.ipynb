# %%
import pandas as pd
import numpy as np

# %%
#!pip install spacy

# %%
df = pd.read_csv('index.csv')

# %%
df.head()
# Out:
#                            question   answere      pdfname
# 0                         Konsesjon       Nei  output1.pdf
# 1                         Odelsrett       Nei  output1.pdf
# 2                           Boplikt       Nei  output1.pdf
# 3                        Driveplikt       Nei  output1.pdf
# 4  Har du kjennskap til eiendommen?  Svar: Ja  output1.pdf

# %%
""" Dette skjema vil være en del av salgsoppgaven """
"""Til orientering vil dette skjema være en del av salgsoppgaven"""
